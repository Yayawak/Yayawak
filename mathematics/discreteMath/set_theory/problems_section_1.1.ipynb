# %%
# !pip install matplotlib-venn

# %%
from matplotlib_venn import venn2
import matplotlib_venn as mplv

# %%
venn2(subsets=(20,4,1))

# %%
venn2(subsets={'10': 2,
              '01': 4,
              '11': 1})

# %%
s1 = set(['A', 'B', 'C', 'D'])
s1
# Out:
# {'A', 'B', 'C', 'D'}

# %%
s2 = set(['C','D','E','F','G'])
s2
# Out:
# {'C', 'D', 'E', 'F', 'G'}

# %%
venn = venn2([s1,s2])

# %%
venn.centers
# Out:
# array([[-0.22558161,  0.        ],
#        [ 0.18046529,  0.        ]])

# %%
venn.set_labels
# Out:
# [Text(-0.22558161195773857, -0.47165296045858324, 'A'),
#  Text(0.1804652895661908, -0.5219929502216332, 'B')]

# %%
venn.get_circle_radius(1)
# Out:
# 0.47682722700889607

# %%
mplv.venn2_circles([s1-{'C'},s2])

# %%
mplv.venn3(subsets=(4,6,1,8,2,3,0))

# %%
# s1 = {'dog'}
s1 = "dog,ant,cat,pig,horse,chicken,duck,goose".split(',')
s2 = "chicken,duck,goose,nemo,dolphin,shark,megalodon".split(',')
s3 = "duck,goose,chicken,dove,crow,song_sparrow,owl,phoenix,hummingbird".split(',')
# eval("set(s1)")
# for i in range(3):
    # print(i)
    # eval(f"s{i+1} = set(s{i+1})")
    # eval(f"s{i+1} = set(s{i+1})")
# # s1

# %%
s1 = set(s1)

# %%
s2 = set(s2)

# %%
s3 = set(s3)

# %%
mplv.venn3([s1,s2,s3])
